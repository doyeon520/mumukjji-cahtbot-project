# %%
pip install pymysql

# %%
#스토어 

import scipy.io
import csv
import pymysql

conn = pymysql.connect(host='127.0.0.1', user='root', db='ourmz', charset='utf8',password='kh98124h')

curs = conn.cursor()
conn.commit()
f = open('C://Users//user//Desktop//새 폴더//1027_SEOUL_STORE_TABLE (1).csv','r', encoding = 'utf-8')
csvReader = csv.reader(f)

for column in csvReader:
    storeID = (column[0])
    menuID = (column[1])
    store_name = (column[2])
    store_addr = (column[3])
    store_lat = (column[4])
    store_lon = (column[5])  
    store_tel= (column[6])
    store_menu = (column[7])
    store_time = (column[8])
    store_info = (column[9])
    store_spc = (column[10])
    store_addr1 = (column[11])
    store_addr2 = (column[12])
    store_addr3 = (column[13])
    review_keyword = (column[14])
    review_for = (column[15])
    review_menu = (column[16])
    store_url = (column[17])
    sql = "insert into store (storeID, menuID, store_name, store_addr, store_lat, store_lon, store_tel, store_menu, store_time, store_info, store_spc, store_addr1, store_addr2, store_addr3, review_keyword, review_for, review_menu, store_url) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    curs.execute(sql, (storeID, menuID, store_name, store_addr, store_lat, store_lon, store_tel, store_menu, store_time, store_info, store_spc, store_addr1, store_addr2, store_addr3, review_keyword, review_for, review_menu, store_url))

#db의 변화 저장
conn.commit()
f.close()
conn.close()

# %%
#gudong

import scipy.io
import csv
import pymysql

conn = pymysql.connect(host='127.0.0.1', user='root', db='ourmz', charset='utf8',password='kh98124h')

curs = conn.cursor()
conn.commit()
f = open('C://Users//user//Desktop//새 폴더//gudongDB.csv','r', encoding = 'utf-8')
csvReader = csv.reader(f)

for column in csvReader:
    gu = (column[0])
    dong = (column[1])
    nx = (column[2])
    ny = (column[3])

    sql = "insert into gudong (gu, dong, nx, ny) values (%s,%s,%s,%s)"
    curs.execute(sql, (gu, dong, nx, ny))

#db의 변화 저장
conn.commit()
f.close()
conn.close()

# %%
#메뉴

import scipy.io
import csv
import pymysql

conn = pymysql.connect(host='127.0.0.1', user='root', db='ourmz', charset='utf8',password='kh98124h')

curs = conn.cursor()
conn.commit()
f = open('C://Users//user//Desktop//새 폴더//1004_MENU_TABLE.csv','r', encoding = 'utf-8')
csvReader = csv.reader(f)

for column in csvReader:
    menuID = (column[0])
    menu_name = (column[1])
    sql = "insert into menu (menuID, menu_name) values (%s, %s)"
    curs.execute(sql, (menuID, menu_name))

#db의 변화 저장
conn.commit()
f.close()
conn.close()

# %%
#시간

import scipy.io
import csv
import pymysql

conn = pymysql.connect(host='127.0.0.1', user='root', db='ourmz', charset='utf8', password='kh98124h')

curs = conn.cursor()
conn.commit()
f = open('C://Users//user//Desktop//새 폴더//1006_HJ_MENU_TIME_TABLE.csv','r', encoding = 'utf-8')
csvReader = csv.reader(f)

for column in csvReader:
    time = (column[0])
    menuID= (column[1])
    sql = "insert into time (time, menuID) values (%s, %s)"
    curs.execute(sql, (time, menuID))

#db의 변화 저장
conn.commit()
f.close()
conn.close()

# %%
#날씨

import scipy.io
import csv
import pymysql

conn = pymysql.connect(host='127.0.0.1', user='root', db='ourmz', charset='utf8',password='kh98124h')

curs = conn.cursor()
conn.commit()
f = open('C://Users//user//Desktop//새 폴더//1006_HJ_MENU_WEATHER_TABLE.csv','r', encoding = 'utf-8')
csvReader = csv.reader(f)

for column in csvReader:
    weather = (column[0])
    menuID= (column[1])
    sql = "insert into weather (weather, menuID) values (%s, %s)"
    curs.execute(sql, (weather, menuID))

#db의 변화 저장
conn.commit()
f.close()
conn.close()

# %%
#가져와지나 확인

import scipy.io
import csv
import pymysql

conn = pymysql.connect(host='127.0.0.1', user='root', db='ourmz', charset='utf8',password='kh98124h')

# Connection 으로부터 Cursor 생성
curs = conn.cursor()

sql = "select * from ourmz.store"
curs.execute(sql)


rows = curs.fetchall()
#print(rows)
print(rows[2])
 
    
#스토어에서 떡볶이 코드 입력 시 상호 하나 출력하기  
sql = "select * from ourmz.store"
sql = "select * from ourmz.store where menuID = 'J00116'"
curs.execute(sql)

rows = curs.fetchall()
print(rows[0][0])
